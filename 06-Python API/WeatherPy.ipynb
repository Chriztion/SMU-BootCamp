# %%
#  Dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# API Key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Load cities.csv
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-75, 100)
lng_range = (-180, 180)

# %%
# Make a list that stores latitudes and longitudes 
lat_lngs = []
cities = []

# Random set of lat lng combos
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city per lat lng 
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    if city not in cities:
        cities.append(city)

# Make sure I have at least 500 cities
len(cities)
# Out:
# 603

# %%
city_7 = cities[8]
city_7
# Out:
# 'rikitea'

# %%
# Build query URL
units = "imperial"
url = f"http://api.openweathermap.org/data/2.5/weather?q={city_7}&appid={weather_api_key}&units={units}"

url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=b9243e2d7b71044b8840d4590278accb&units=imperial'

# %%
response = requests.get(url).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1588654220,
#  'id': 4030556,
#  'main': {'feels_like': 68.54,
#           'grnd_level': 1015,
#           'humidity': 71,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 73.17,
#           'temp_max': 73.17,
#           'temp_min': 73.17},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1588605677, 'sunset': 1588645909},
#  'timezone': -32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 16.24}}

# %%
#Make lists to append to *Might not need this 
lats = []
longs = []
temps = []
humids = []
pressures = []
winds = []
clouds = []

citiesFound = []
counter = 0

# %%
 
units = 'imperial'

# Empty the lists
city_list = []
lats = []
long = []
temp = []
wind = []
humid = []
cloud = []
country = []
pressure = []

#Count to zero for displaying message
count = 0

for city in cities:
    
    count += 1
    # Use a try/except function 
    try: 
        
        query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q={city}"
        response = requests.get(query_url).json()
        
        #Append the list 
        lats.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        pressure.append(response['main']['pressure'])
        
        
        city_list.append(city)
        
        
        print(f"Printing city #{count} out of {len(cities)} -- {city}")

    except Exception as e:
        
        print(f"City #{count} out of {len(cities)} missing {e}... skipping {city}.")
        next
 
    
    #put in time limit to avoid hitting the rate limit 
    time.sleep(2)
# Out:
# Printing city #1 out of 603 -- portland
# Printing city #2 out of 603 -- punta arenas
# Printing city #3 out of 603 -- avarua
# Printing city #4 out of 603 -- cape town
# Printing city #5 out of 603 -- hilo
# Printing city #6 out of 603 -- upernavik
# Printing city #7 out of 603 -- aracati
# Printing city #8 out of 603 -- saint-philippe
# Printing city #9 out of 603 -- rikitea
# Printing city #10 out of 603 -- broome
# Printing city #11 out of 603 -- madras
# Printing city #12 out of 603 -- atuona
# Printing city #13 out of 603 -- ugoofaaru
# Printing city #14 out of 603 -- sitka
# Printing city #15 out of 603 -- fare
# Printing city #16 out of 603 -- coquimbo
# Printing city #17 out of 603 -- cherskiy
# Printing city #18 out of 603 -- saldanha
# Printing city #19 out of 603 -- dikson
# Printing city #20 out of 603 -- lebu
# Printing city #21 out of 603 -- codrington
# Printing city #22 out of 603 -- san jose
# Printing city #23 out of 603 -- busselton
# Printing city #24 out of 603 -- lorengau
# Printing city #25 out of 603 -- grindavik
# City #26 out of 603 missing 'coord'... skipping barentsburg.
# Printing city #27 out of 603 -- provideniya
# City #28 out of 603 missing 'coord'... skipping taolanaro.
# Printing city #29 out of 603 -- puerto ayora
# Printing city #30 out of 603 -- lima
# Printing city #31 out of 603 -- sao jose da coroa grande
# City #32 out of 603 missing 'coord'... skipping sorvag.
# Printing city #33 out of 603 -- hithadhoo
# City #34 out of 603 missing 'coord'... skipping illoqqortoormiut.
# Printing city #35 out of 603 -- yarke pole
# Printing city #36 out of 603 -- evensk
# Printing city #37 out of 603 -- namibe
# City #38 out of 603 missing 'coord'... skipping arkhangelos.
# Printing city #39 out of 603 -- gwadar
# Printing city #40 out of 603 -- bara
# Printing city #41 out of 603 -- thompson
# Printing city #42 out of 603 -- yar-sale
# Printing city #43 out of 603 -- waitati
# Printing city #44 out of 603 -- chokurdakh
# Printing city #45 out of 603 -- havre-saint-pierre
# City #46 out of 603 missing 'coord'... skipping palabuhanratu.
# Printing city #47 out of 603 -- naze
# Printing city #48 out of 603 -- saskylakh
# Printing city #49 out of 603 -- plettenberg bay
# Printing city #50 out of 603 -- airai
# Printing city #51 out of 603 -- mangrol
# Printing city #52 out of 603 -- sangueya
# Printing city #53 out of 603 -- bluff
# Printing city #54 out of 603 -- tasiilaq
# Printing city #55 out of 603 -- divnoye
# City #56 out of 603 missing 'coord'... skipping attawapiskat.
# Printing city #57 out of 603 -- bonthe
# Printing city #58 out of 603 -- tezu
# Printing city #59 out of 603 -- nhulunbuy
# Printing city #60 out of 603 -- mataura
# Printing city #61 out of 603 -- gastello
# Printing city #62 out of 603 -- new norfolk
# Printing city #63 out of 603 -- ostrovnoy
# Printing city #64 out of 603 -- butaritari
# Printing city #65 out of 603 -- nuuk
# Printing city #66 out of 603 -- bamiantong
# Printing city #67 out of 603 -- vostok
# Printing city #68 out of 603 -- lompoc
# Printing city #69 out of 603 -- nome
# Printing city #70 out of 603 -- avera
# Printing city #71 out of 603 -- muros
# Printing city #72 out of 603 -- klaksvik
# Printing city #73 out of 603 -- nanortalik
# City #74 out of 603 missing 'coord'... skipping mys shmidta.
# Printing city #75 out of 603 -- tigil
# Printing city #76 out of 603 -- vaini
# Printing city #77 out of 603 -- sahuaripa
# Printing city #78 out of 603 -- fortuna
# Printing city #79 out of 603 -- port alfred
# Printing city #80 out of 603 -- tuktoyaktuk
# Printing city #81 out of 603 -- east london
# Printing city #82 out of 603 -- yining
# Printing city #83 out of 603 -- acarau
# Printing city #84 out of 603 -- mbandaka
# Printing city #85 out of 603 -- venado tuerto
# Printing city #86 out of 603 -- pevek
# Printing city #87 out of 603 -- eureka
# City #88 out of 603 missing 'coord'... skipping maimon.
# Printing city #89 out of 603 -- ishinomaki
# Printing city #90 out of 603 -- barrow
# Printing city #91 out of 603 -- kavaratti
# Printing city #92 out of 603 -- hambantota
# City #93 out of 603 missing 'coord'... skipping belushya guba.
# Printing city #94 out of 603 -- port hardy
# Printing city #95 out of 603 -- longyearbyen
# Printing city #96 out of 603 -- port elizabeth
# Printing city #97 out of 603 -- bredasdorp
# Printing city #98 out of 603 -- laguna
# Printing city #99 out of 603 -- narsaq
# Printing city #100 out of 603 -- denpasar
# Printing city #101 out of 603 -- sao joao da barra
# Printing city #102 out of 603 -- nelson bay
# Printing city #103 out of 603 -- pimentel
# Printing city #104 out of 603 -- bethel
# Printing city #105 out of 603 -- hasaki
# Printing city #106 out of 603 -- watsa
# Printing city #107 out of 603 -- maridi
# Printing city #108 out of 603 -- chapais
# Printing city #109 out of 603 -- henties bay
# Printing city #110 out of 603 -- baghdad
# Printing city #111 out of 603 -- faanui
# Printing city #112 out of 603 -- qaanaaq
# Printing city #113 out of 603 -- san patricio
# City #114 out of 603 missing 'coord'... skipping garcina.
# Printing city #115 out of 603 -- castro
# Printing city #116 out of 603 -- oussouye
# Printing city #117 out of 603 -- praia da vitoria
# Printing city #118 out of 603 -- hobart
# Printing city #119 out of 603 -- bairiki
# Printing city #120 out of 603 -- neepawa
# City #121 out of 603 missing 'coord'... skipping saleaula.
# Printing city #122 out of 603 -- georgetown
# Printing city #123 out of 603 -- beterou
# Printing city #124 out of 603 -- bihac
# Printing city #125 out of 603 -- leningradskiy
# Printing city #126 out of 603 -- sembakung
# Printing city #127 out of 603 -- shingu
# Printing city #128 out of 603 -- aripuana
# Printing city #129 out of 603 -- say
# Printing city #130 out of 603 -- nikolskoye
# Printing city #131 out of 603 -- xiangxiang
# Printing city #132 out of 603 -- hermanus
# Printing city #133 out of 603 -- kribi
# Printing city #134 out of 603 -- nha trang
# Printing city #135 out of 603 -- port blair
# Printing city #136 out of 603 -- flinders
# Printing city #137 out of 603 -- tabou
# Printing city #138 out of 603 -- te anau
# Printing city #139 out of 603 -- shumyachi
# Printing city #140 out of 603 -- mariakani
# Printing city #141 out of 603 -- porto novo
# Printing city #142 out of 603 -- kavieng
# Printing city #143 out of 603 -- khatanga
# Printing city #144 out of 603 -- lavrentiya
# Printing city #145 out of 603 -- beibei
# Printing city #146 out of 603 -- nanae
# Printing city #147 out of 603 -- vigrestad
# Printing city #148 out of 603 -- bambanglipuro
# Printing city #149 out of 603 -- phan thiet
# Printing city #150 out of 603 -- ushuaia
# Printing city #151 out of 603 -- sucre
# Printing city #152 out of 603 -- wufeng
# Printing city #153 out of 603 -- kapaa
# Printing city #154 out of 603 -- madera
# Printing city #155 out of 603 -- albany
# Printing city #156 out of 603 -- hazorasp
# City #157 out of 603 missing 'coord'... skipping bargal.
# Printing city #158 out of 603 -- fethiye
# Printing city #159 out of 603 -- mocuba
# Printing city #160 out of 603 -- menongue
# Printing city #161 out of 603 -- mancora
# Printing city #162 out of 603 -- pueblo nuevo
# Printing city #163 out of 603 -- pangai
# Printing city #164 out of 603 -- jamestown
# City #165 out of 603 missing 'coord'... skipping rungata.
# Printing city #166 out of 603 -- yellowknife
# Printing city #167 out of 603 -- mar del plata
# Printing city #168 out of 603 -- nenjiang
# Printing city #169 out of 603 -- carnarvon
# Printing city #170 out of 603 -- san cristobal
# Printing city #171 out of 603 -- sribne
# Printing city #172 out of 603 -- clyde river
# Printing city #173 out of 603 -- kodiak
# Printing city #174 out of 603 -- praia
# Printing city #175 out of 603 -- kutum
# Printing city #176 out of 603 -- ponta delgada
# Printing city #177 out of 603 -- barra
# Printing city #178 out of 603 -- shenjiamen
# Printing city #179 out of 603 -- saint george
# Printing city #180 out of 603 -- husavik
# Printing city #181 out of 603 -- lewistown
# Printing city #182 out of 603 -- rio gallegos
# Printing city #183 out of 603 -- poum
# Printing city #184 out of 603 -- vestmannaeyjar
# Printing city #185 out of 603 -- kenai
# Printing city #186 out of 603 -- bogalusa
# Printing city #187 out of 603 -- atikokan
# Printing city #188 out of 603 -- talara
# Printing city #189 out of 603 -- willmar
# Printing city #190 out of 603 -- souillac
# Printing city #191 out of 603 -- caravelas
# City #192 out of 603 missing 'coord'... skipping vaitupu.
# Printing city #193 out of 603 -- kisanga
# Printing city #194 out of 603 -- agirish
# Printing city #195 out of 603 -- yulara
# Printing city #196 out of 603 -- suslovo
# Printing city #197 out of 603 -- vizinga
# Printing city #198 out of 603 -- bambous virieux
# Printing city #199 out of 603 -- japura
# Printing city #200 out of 603 -- shubarshi
# Printing city #201 out of 603 -- vardo
# City #202 out of 603 missing 'coord'... skipping karaul.
# Printing city #203 out of 603 -- ryotsu
# Printing city #204 out of 603 -- plainview
# Printing city #205 out of 603 -- zhigansk
# Printing city #206 out of 603 -- treinta y tres
# Printing city #207 out of 603 -- nizhniy kuranakh
# Printing city #208 out of 603 -- bar harbor
# Printing city #209 out of 603 -- bengkulu
# Printing city #210 out of 603 -- iqaluit
# Printing city #211 out of 603 -- goderich
# Printing city #212 out of 603 -- half moon bay
# Printing city #213 out of 603 -- port lincoln
# City #214 out of 603 missing 'coord'... skipping kesennuma.
# Printing city #215 out of 603 -- rio bueno
# Printing city #216 out of 603 -- antofagasta
# Printing city #217 out of 603 -- wanning
# Printing city #218 out of 603 -- byron bay
# City #219 out of 603 missing 'coord'... skipping amderma.
# Printing city #220 out of 603 -- rezina
# Printing city #221 out of 603 -- kruisfontein
# Printing city #222 out of 603 -- nalut
# Printing city #223 out of 603 -- ilulissat
# Printing city #224 out of 603 -- inhambane
# Printing city #225 out of 603 -- norman wells
# Printing city #226 out of 603 -- sola
# Printing city #227 out of 603 -- ambilobe
# Printing city #228 out of 603 -- berlevag
# Printing city #229 out of 603 -- tagusao
# Printing city #230 out of 603 -- gizycko
# Printing city #231 out of 603 -- kikwit
# Printing city #232 out of 603 -- new iberia
# Printing city #233 out of 603 -- pisco
# Printing city #234 out of 603 -- marawi
# Printing city #235 out of 603 -- ancud
# Printing city #236 out of 603 -- tahoua
# Printing city #237 out of 603 -- kuytun
# Printing city #238 out of 603 -- temeni
# Printing city #239 out of 603 -- mahenge
# Printing city #240 out of 603 -- rundu
# Printing city #241 out of 603 -- waipawa
# Printing city #242 out of 603 -- minas
# Printing city #243 out of 603 -- qaqortoq
# Printing city #244 out of 603 -- papineauville
# Printing city #245 out of 603 -- fazilka
# Printing city #246 out of 603 -- san carlos de bariloche
# Printing city #247 out of 603 -- phibun mangsahan
# Printing city #248 out of 603 -- oytal
# Printing city #249 out of 603 -- ormara
# Printing city #250 out of 603 -- mbocayaty
# Printing city #251 out of 603 -- strangnas
# City #252 out of 603 missing 'coord'... skipping tumannyy.
# Printing city #253 out of 603 -- nerchinskiy zavod
# Printing city #254 out of 603 -- belaya gora
# Printing city #255 out of 603 -- mahebourg
# Printing city #256 out of 603 -- sur
# Printing city #257 out of 603 -- rawdon
# Printing city #258 out of 603 -- cavalcante
# Printing city #259 out of 603 -- touros
# Printing city #260 out of 603 -- kismayo
# Printing city #261 out of 603 -- xingcheng
# Printing city #262 out of 603 -- kushmurun
# Printing city #263 out of 603 -- bundaberg
# City #264 out of 603 missing 'coord'... skipping ngukurr.
# Printing city #265 out of 603 -- taoudenni
# Printing city #266 out of 603 -- hinton
# Printing city #267 out of 603 -- strelka
# Printing city #268 out of 603 -- tabas
# Printing city #269 out of 603 -- kahului
# Printing city #270 out of 603 -- khairpur nathan shah
# Printing city #271 out of 603 -- raga
# Printing city #272 out of 603 -- luderitz
# Printing city #273 out of 603 -- hamilton
# Printing city #274 out of 603 -- guerrero negro
# Printing city #275 out of 603 -- kochki
# Printing city #276 out of 603 -- akhtubinsk
# Printing city #277 out of 603 -- richards bay
# Printing city #278 out of 603 -- katsuura
# Printing city #279 out of 603 -- kaitangata
# Printing city #280 out of 603 -- carballo
# Printing city #281 out of 603 -- marzuq
# Printing city #282 out of 603 -- bastia
# Printing city #283 out of 603 -- cidreira
# Printing city #284 out of 603 -- whittlesea
# Printing city #285 out of 603 -- dudinka
# Printing city #286 out of 603 -- cairns
# Printing city #287 out of 603 -- troitskoye
# Printing city #288 out of 603 -- natchez
# Printing city #289 out of 603 -- port-gentil
# Printing city #290 out of 603 -- chipata
# Printing city #291 out of 603 -- alamosa
# Printing city #292 out of 603 -- severiano melo
# Printing city #293 out of 603 -- ahipara
# Printing city #294 out of 603 -- visby
# Printing city #295 out of 603 -- kajaani
# Printing city #296 out of 603 -- miri
# Printing city #297 out of 603 -- torbay
# Printing city #298 out of 603 -- mattru
# City #299 out of 603 missing 'coord'... skipping marcona.
# Printing city #300 out of 603 -- sibolga
# Printing city #301 out of 603 -- chase
# Printing city #302 out of 603 -- kayerkan
# Printing city #303 out of 603 -- tuatapere
# Printing city #304 out of 603 -- kirakira
# City #305 out of 603 missing 'coord'... skipping nizhneyansk.
# Printing city #306 out of 603 -- bontang
# Printing city #307 out of 603 -- storforshei
# Printing city #308 out of 603 -- aklavik
# Printing city #309 out of 603 -- mount gambier
# Printing city #310 out of 603 -- marsh harbour
# Printing city #311 out of 603 -- copiapo
# Printing city #312 out of 603 -- tiksi
# Printing city #313 out of 603 -- domoni
# Printing city #314 out of 603 -- ribeira grande
# Printing city #315 out of 603 -- beloha
# Printing city #316 out of 603 -- dingle
# Printing city #317 out of 603 -- alofi
# Printing city #318 out of 603 -- yeniseysk
# Printing city #319 out of 603 -- raahe
# City #320 out of 603 missing 'coord'... skipping maghama.
# Printing city #321 out of 603 -- yabelo
# Printing city #322 out of 603 -- orlik
# Printing city #323 out of 603 -- sao filipe
# Printing city #324 out of 603 -- manicore
# Printing city #325 out of 603 -- dharchula
# Printing city #326 out of 603 -- ponta do sol
# Printing city #327 out of 603 -- shimoda
# Printing city #328 out of 603 -- price
# Printing city #329 out of 603 -- uyuni
# City #330 out of 603 missing 'coord'... skipping stoyba.

# %%
counter

# %%
weather_df = pd.DataFrame()
weather_df["cities"] = citiesFound
weather_df["latitude"] = lats
weather_df["longitude"] = longs
weather_df["temperature"] = temps
weather_df["humidity"] = humids
weather_df["pressure"] = pressures
weather_df["wind_speed"] = winds
weather_df["cloudiness"] = clouds

weather_df.head()

# %%
len(weather_df)

# %%
weather_df.describe()

# %%
# check the cities that have over 100% humidity
mask = weather_df.humidity <= 100
weather_sub = weather_df.loc[mask].reset_index(drop=True)

weather_sub.head()

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
weather_sub.to_csv("weatherPyData.csv", index=False)

# %%
#View the new exported csv and check the data

new_df = pd.read_csv("weatherPyData.csv")

new_df.head()

# %%
# Scatter Plots (Lat v. Temp, Lat v. Humidity, Lat v. Cloudiness, Lat v. Wind Speed)
# Add explanations under plots
#Lat v. Temp
plt.scatter(new_df.latitude, new_df.temperature, color="purple", marker="*")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Latitude vs Temperature", fontsize=14, fontweight="bold")
plt.show()

# %%
#Lat v. Humidity
plt.scatter(new_df.latitude, new_df.humidity, color="red", marker="*")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs Humidity", fontsize=14, fontweight="bold")
plt.show()

# %%
#Lat v. Cloudiness
plt.scatter(new_df.latitude, new_df.cloudiness, color="blue", marker="*")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs Cloudiness", fontsize=14, fontweight="bold")
plt.show()

# %%
#Lat v. Wind Speed
plt.scatter(new_df.latitude, new_df.wind_speed, color="lightblue", marker="*")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs Wind Speed", fontsize=14, fontweight="bold")
plt.show()

# %%
#Linear Regression for each hemisphere North, South
# north Hemi
northernHemi = new_df.latitude >= 0
north = df.loc[northernHemi].reset_index(drop=True)

north.head()

# %%
# south Hemi
southernHemi = new_df.latitude < 0
south = df.loc[southernHemi].reset_index(drop=True)

south.head()

# %%
# Latitude vs Temperature (North) w/ r squared 
x_values = north['latitude']
y_values = north['temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color="purple")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title("Latitude vs Temperature in the North")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()

# %%
# Latitude vs Temperature (South) w/ r squared 
x_values = south['latitude']
y_values = south['temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color="purple")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title("Latitude vs Temperature in the South")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()

# %%
# Latitude vs. Humidity (North) w/ r squared
x_values = north['latitude']
y_values = north['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Latitude vs Humidity in the North")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()

# %%
# Latitude vs. Humidity (South) w/ r squared
x_values = south['latitude']
y_values = south['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Latitude vs Humidity in the South")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()

# %%
# Latitude vs Cloudiness (North) w/ r squared 
x_values = north['latitude']
y_values = north['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color="blue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Latitude vs Cloudiness in the North")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()

# %%
# Latitude vs Cloudiness (South) w/ r squared 
x_values = south['latitude']
y_values = south['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color="blue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Latitude vs Cloudiness in the South")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()

# %%
# Latitude vs Wind Speed (North) w/ r squared 
x_values = north['latitude']
y_values = north['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color="lightblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Latitude vs Wind Speed in the North")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()

# %%
# Latitude vs Wind Speed (south) w/ r squared
x_values = south['latitude']
y_values = south['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color="lightblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Latitude vs Wind Speed in the South")
print(f"The r-squared is: {rvalue**2}")
print(f"The p-value is: {pvalue}")
plt.show()
